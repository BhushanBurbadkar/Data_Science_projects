# %%
#Importing Required Lib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("bike_buyers_clean.csv") #Reading the csv file using pandas
print(data.head(10))    #Printing first ten values of data
# Out:
#       ID Marital Status  Gender  Income  Children            Education  \
# 0  12496        Married  Female   40000         1            Bachelors
# 1  24107        Married    Male   30000         3      Partial College
# 2  14177        Married    Male   80000         5      Partial College
# 3  24381         Single    Male   70000         0            Bachelors
# 4  25597         Single    Male   30000         0            Bachelors
# 5  13507        Married  Female   10000         2      Partial College
# 6  27974         Single    Male  160000         2          High School
# 7  19364        Married    Male   40000         1            Bachelors
# 8  22155        Married    Male   20000         2  Partial High School
# 9  19280        Married    Male   20000         2      Partial College
#
#        Occupation Home Owner  Cars Commute Distance   Region  Age  \
# 0  Skilled Manual        Yes     0        0-1 Miles   Europe   42
# ...

# %% [markdown]
# **Data Analysis**

# %%
print(data.info())  #printing Infio of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1000 non-null   int64
#  1   Marital Status    1000 non-null   object
#  2   Gender            1000 non-null   object
#  3   Income            1000 non-null   int64
#  4   Children          1000 non-null   int64
#  5   Education         1000 non-null   object
#  6   Occupation        1000 non-null   object
#  7   Home Owner        1000 non-null   object
#  8   Cars              1000 non-null   int64
#  9   Commute Distance  1000 non-null   object
#  10  Region            1000 non-null   object
#  11  Age               1000 non-null   int64
#  12  Purchased Bike    1000 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 101.7+ KB
# None

# %%
print(data.dtypes)  #printing datatypes
# Out:
# ID                   int64
# Marital Status      object
# Gender              object
# Income               int64
# Children             int64
# Education           object
# Occupation          object
# Home Owner          object
# Cars                 int64
# Commute Distance    object
# Region              object
# Age                  int64
# Purchased Bike      object
# dtype: object

# %%
print(data.isnull().sum())  #To analysis if there are any null values in data
# Out:
# ID                  0
# Marital Status      0
# Gender              0
# Income              0
# Children            0
# Education           0
# Occupation          0
# Home Owner          0
# Cars                0
# Commute Distance    0
# Region              0
# Age                 0
# Purchased Bike      0
# dtype: int64

# %%
print(data.describe())   #To describe the data
# Out:
#                  ID         Income     Children         Cars          Age
# count   1000.000000    1000.000000  1000.000000  1000.000000  1000.000000
# mean   19965.992000   56140.000000     1.908000     1.452000    44.190000
# std     5347.333948   31081.609779     1.626094     1.124705    11.353537
# min    11000.000000   10000.000000     0.000000     0.000000    25.000000
# 25%    15290.750000   30000.000000     0.000000     1.000000    35.000000
# 50%    19744.000000   60000.000000     2.000000     1.000000    43.000000
# 75%    24470.750000   70000.000000     3.000000     2.000000    52.000000
# max    29447.000000  170000.000000     5.000000     4.000000    89.000000

# %%
print(data.value_counts())
# Out:
# ID     Marital Status  Gender  Income  Children  Education        Occupation      Home Owner  Cars  Commute Distance  Region         Age  Purchased Bike
# 11000  Married         Male    90000   2         Bachelors        Professional    Yes         0     1-2 Miles         Pacific        40   Yes               1
# 23089  Married         Male    40000   0         Partial College  Skilled Manual  Yes         1     5-10 Miles        North America  28   No                1
# 22864  Married         Male    90000   2         Partial College  Professional    No          0     5-10 Miles        North America  49   Yes               1
# 22918  Single          Male    80000   5         Graduate Degree  Management      Yes         3     0-1 Miles         Pacific        40   No                1
# 22930  Married         Male    90000   4         Bachelors        Professional    Yes         0     1-2 Miles         Pacific        38   Yes               1
# ...

# %%
print(data.head(50))
# Out:
#        ID Marital Status  Gender  Income  Children            Education  \
# 0   12496        Married  Female   40000         1            Bachelors
# 1   24107        Married    Male   30000         3      Partial College
# 2   14177        Married    Male   80000         5      Partial College
# 3   24381         Single    Male   70000         0            Bachelors
# 4   25597         Single    Male   30000         0            Bachelors
# 5   13507        Married  Female   10000         2      Partial College
# 6   27974         Single    Male  160000         2          High School
# 7   19364        Married    Male   40000         1            Bachelors
# 8   22155        Married    Male   20000         2  Partial High School
# 9   19280        Married    Male   20000         2      Partial College
# 10  22173        Married  Female   30000         3          High School
# 11  12697         Single  Female   90000         0            Bachelors
# ...

# %%
print(data["Purchased Bike"].value_counts())   #To get the total value count of purchased bike
# Out:
# No     519
# Yes    481
# Name: Purchased Bike, dtype: int64

# %% [markdown]
# **Data visualization**

# %%
#Defining a function to set the size of the grah
def setplt(x = 15, y = 9):
    f, v = plt.subplots(figsize=(x, y))
    sns.despine(f, left=True, bottom=True)

# %%
d1 = data[["Income", "Children", "Cars", "Age","Purchased Bike"]]
v1 = sns.pairplot(data = d1, hue = "Purchased Bike")   #Using pairplot to get Purchased Bike detials

# %%
v2 = sns.jointplot(x = "Age", y = "Income", data = data, kind = "scatter", height = 10, ratio = 10)   #usnig jointplot to show relationship between income and age  
plt.show()

# %%
v3 = setplt() #callling the function setplt which we defined 
v3 = sns.countplot(x = "Purchased Bike", data = data, hue = "Gender", palette = ["Turquoise", "Blue"])  #Plotting a countpolt using seaborn for gender to know which gender has purcchased bike
plt.show()

# %%
v4 = setplt()
v4 = sns.countplot(x = "Purchased Bike", data = data, hue = "Region", palette = ["Red", "Blue", "Green"]) #Using countplot to know Purchased Bike based on region
plt.show()

# %%
v5 = setplt()
v5 = sns.countplot(x = "Purchased Bike", data = data, hue = "Occupation")  #Using countplot to get Purchased Bikebased on Occupation
plt.show()

# %%
v6 = setplt()
v6 = sns.countplot(x = "Age", data = data, hue = "Purchased Bike")    #using countplot to get Purchased Bike based on age
plt.show()

# %%
v7 = setplt()
v7= sns.lineplot(x = "Marital Status", y = "Income",data = data, hue = "Purchased Bike", color = "cyan")    #Using lineplot to get Purchased Bike based Marital Status and Income
plt.show()

# %%
v8 = setplt()
v8 = sns.boxenplot(x = "Purchased Bike", y = "Income",data = data, palette = "Set2")   #Using boxenplot to get Purchased Bike based on Income
plt.show()

# %%
v9 = setplt()
v9 = sns.lineplot(x = "Income", y = "Purchased Bike", data = data, color = "Gray")    #Using loneplot to show Purchased Bike based on income
plt.show()

# %%
v10 = setplt()
v10 = sns.histplot(x = "Occupation", hue = "Purchased Bike", data = data, multiple = "dodge", shrink = 0.6, palette = sns.blend_palette(["Yellow", "Green"], 2))   #Using histp;t to show Purchased Bike based on Occupation 
plt.show()

# %%
v11 = setplt()
v11 = sns.scatterplot(x = "Income", y = "Age", data = data, hue = "Purchased Bike")  #USing scatterplot to show Purchased Bike based on income and age
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder    #Importing label encoder to convert catogerical values to numeric

#converting catogerical values to numeric
label_encoder = LabelEncoder() 

data["Marital Status"] = label_encoder.fit_transform(data["Marital Status"])
data["Gender"] = label_encoder.fit_transform(data["Gender"])
data["Education"] = label_encoder.fit_transform(data["Education"])
data["Occupation"] = label_encoder.fit_transform(data["Occupation"])
data["Home Owner"] = label_encoder.fit_transform(data["Home Owner"])
data["Commute Distance"] = label_encoder.fit_transform(data["Commute Distance"])
data["Region"] = label_encoder.fit_transform(data["Region"])
data["Purchased Bike"] = label_encoder.fit_transform(data["Purchased Bike"])
data.head(50)
# Out:
#        ID  Marital Status  Gender  Income  Children  Education  Occupation  \
# 0   12496               0       0   40000         1          0           4
# 1   24107               0       1   30000         3          3           0
# 2   14177               0       1   80000         5          3           3
# 3   24381               1       1   70000         0          0           3
# 4   25597               1       1   30000         0          0           0
# 5   13507               0       0   10000         2          3           2
# 6   27974               1       1  160000         2          2           1
# 7   19364               0       1   40000         1          0           4
# 8   22155               0       1   20000         2          4           0
# 9   19280               0       1   20000         2          3           2
# 10  22173               0       0   30000         3          2           4
# ...

# %%
v12 = setplt()
corrMatrix = data.corr() #Used to get corelation between every column
v12 = sns.heatmap(corrMatrix, annot = True, cmap = "YlGnBu") #using heatmap to show corelation
plt.show()

# %% [markdown]
# **Machine Learning Model**

# %%
data.drop("ID", axis = 1, inplace = True)   #Droping Id since we do nir need it

# %%
print(data.head(10))
# Out:
#    Marital Status  Gender  Income  Children  Education  Occupation  \
# 0               0       0   40000         1          0           4
# 1               0       1   30000         3          3           0
# 2               0       1   80000         5          3           3
# 3               1       1   70000         0          0           3
# 4               1       1   30000         0          0           0
# 5               0       0   10000         2          3           2
# 6               1       1  160000         2          2           1
# 7               0       1   40000         1          0           4
# 8               0       1   20000         2          4           0
# 9               0       1   20000         2          3           2
#
#    Home Owner  Cars  Commute Distance  Region  Age  Purchased Bike
# 0           1     0                 0       0   42               0
# 1           1     1                 0       0   43               0
# ...

# %%
data.head(10)
# Out:
#    Marital Status  Gender  Income  Children  Education  Occupation  \
# 0               0       0   40000         1          0           4
# 1               0       1   30000         3          3           0
# 2               0       1   80000         5          3           3
# 3               1       1   70000         0          0           3
# 4               1       1   30000         0          0           0
# 5               0       0   10000         2          3           2
# 6               1       1  160000         2          2           1
# 7               0       1   40000         1          0           4
# 8               0       1   20000         2          4           0
# 9               0       1   20000         2          3           2
#
#    Home Owner  Cars  Commute Distance  Region  Age  Purchased Bike
# 0           1     0                 0       0   42               0
# 1           1     1                 0       0   43               0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
#Defining Dependent and Independent Variables
X=data[["Income", "Age"]]
y=data["Purchased Bike"]

# %%
#Split data
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size = 0.30)

# %%
#Training the model
model = RandomForestClassifier(n_estimators = 240, max_depth = 10, random_state = 1)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=240, random_state=1)

# %%
#Printing accuracy of the model
score1 = model.score(X_train, y_train)
score2 = model.score(X_test, y_test)


print("Training set accuracy: ", "%.3f"%(score1))
print("Test set accuracy: ", "%.3f"%(score2))
# Out:
# Training set accuracy:  0.837
# Test set accuracy:  0.600

# %%
#Comparing Test Data vs Predicted Data
i = 0
y_pred = model.predict(X_test)
test_result = list(y_test)
#for i in range(len(y_test)):
for i in range(10):
    print("-----------------------")
    print("Case:", i+1)
    print(y_pred[i])
    print(test_result[i])
    if y_pred[i] == test_result[i]:
        print("Prediction is correct")
    else:
        print("Prediction is incorrect")
# Out:
# -----------------------
# Case: 1
# 1
# 1
# Prediction is correct
# -----------------------
# Case: 2
# 1
# 1
# Prediction is correct
# -----------------------
# Case: 3
# 0
# 0
# Prediction is correct
# -----------------------
# Case: 4
# 1
# 1
# Prediction is correct
# -----------------------
# Case: 5
# 0
# 0
# Prediction is correct
# -----------------------
# Case: 6
# 0
# 1
# Prediction is incorrect
# -----------------------
# Case: 7
# 0
# 0
# Prediction is correct
# -----------------------
# Case: 8
# 1
# 1
# Prediction is correct
# -----------------------
# Case: 9
# 0
# 1
# Prediction is incorrect
# -----------------------
# Case: 10
# 0
# 1
# Prediction is incorrect

# %%
#Displaying confusion matrix of the model

from sklearn import metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay


cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix = cm)


disp.plot()
plt.show()

# %%
#Statistical Analysis
from sklearn.model_selection import cross_validate
clf = []
clf.append(RandomForestClassifier())

classifier_name = []
mean_value = []
std_value = []

scores = cross_validate(model, X_train, y_train)
print("---------------------------------")
print("Random Forest Classifier")
print("---------------------------------")
    
for key, values in scores.items():
        
    classifier_name.append(clf)
    mean_value.append(values.mean())
    std_value.append(values.std())
        
    print(key," mean ", values.mean())
    print(key," std ", values.std())
# Out:
# ---------------------------------
# Random Forest Classifier
# ---------------------------------
# fit_time  mean  0.37169809341430665
# fit_time  std  0.004868824965256225
# score_time  mean  0.03355493545532227
# score_time  std  0.0034363684380116838
# test_score  mean  0.6471428571428571
# test_score  std  0.03213491965486285

# %%
#from sklearn.metrics import classification_report
from sklearn.metrics import classification_report
# Printing classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.61      0.62       158
#            1       0.58      0.58      0.58       142
#
#     accuracy                           0.60       300
#    macro avg       0.60      0.60      0.60       300
# weighted avg       0.60      0.60      0.60       300
